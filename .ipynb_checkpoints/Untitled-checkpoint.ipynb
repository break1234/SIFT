# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load the image

# %%
img = cv2.imread('1.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Correct BGR to RGB channel
plt.imshow(img)

# %% [markdown]
# Convert image to Graysclae

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')

# %% [markdown]
# Instantiate SIFT feature extractor and find keypoints

# %%
# sift = cv2.xfeatures2d.SIFT_create()
# (kps, descs) = sift.detectAndCompute(gray,None)
kp = sift.detect(gray,None)

# %% [markdown]
# Draw keypoints on the image

# %%
img_with_kps = cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(img_with_kps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d1d64123794f> in <module>()
# ----> 1 img_with_kps = cv2.drawKeypoints(gray,kp,'image',flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#       2 plt.imshow(img_with_kps)
#
# TypeError: outImage is not a numpy array, neither a scalar

# %%
gray.shape
# descs.shape
# Out:
# (768, 1366)
